# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("package.csv")
# df = df.iloc[:, [0, 2]]
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df["cgpa"], df["package"])
plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
X = df.iloc[:, :1]
y = df.iloc[:, 1]
(y)
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=2
)
# y_test

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()

lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

y_pred = lr.predict(X_test)

print(f"R Square score : {r2_score(y_pred, y_test)}")
# Out:
# R Square score : 0.6626575570753073

# %%
plt.scatter(df["cgpa"], df["package"])

plt.plot(X_test, y_pred, color="purple")

plt.xlabel("CGPA")
plt.ylabel("Package")
# Out:
# Text(0, 0.5, 'Package')

# %%
lr.coef_
# Out:
# array([0.55795197])

# %%
lr.intercept_
# Out:
# np.float64(-0.8961119222429144)

# %%
(X_test.values[0],y_test.values[0])
# Out:
# (array([8.58]), np.float64(4.1))

# %%
m = lr.coef_
c = lr.intercept_

temp = m*np.array(8.58).reshape(1, 1) + c

# %%
temp
# Out:
# array([[3.89111601]])

# %%
lr.predict(np.array(8.58).reshape(1, 1))
# Out:
# /Users/ayushthasale07/Sarg<3/PlainML/.venv/lib/python3.9/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.89111601])
