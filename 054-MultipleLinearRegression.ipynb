# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
X, y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({"feature1": X[:, 0], "feature2": X[:, 1], "y": y})
df.head()
# Out:
#    feature1  feature2           y
# 0 -1.963487  1.195177   10.321166
# 1 -1.493499  0.934635   53.577656
# 2 -0.177066  0.643095   42.127600
# 3  0.349706 -0.206608   10.192934
# 4 -1.540674 -1.278671 -148.921308

# %%
fig = px.scatter_3d(df, x="feature1", y="feature2", z="y")
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,  random_state=3)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print(f"MAE : {mean_absolute_error(y_pred, y_test)}")
print(f"MSE : {mean_squared_error(y_pred, y_test)}")
# print(f"RMSE : {root_mean_squared_error(y_pred, y_test)}")
print(f"R2 : {r2_score(y_test, y_pred)}")
# Out:
# MAE : 39.40132084075195
# MSE : 2495.817440233709
# R2 : 0.7047813449232962

# %%
lr.coef_
# Out:
# array([28.64808704, 74.343153  ])

# %%
lr.intercept_
# Out:
# np.float64(6.288280015032045)
